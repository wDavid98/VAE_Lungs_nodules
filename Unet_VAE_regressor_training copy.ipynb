# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['TF_ENABLE_ONEDNN_OPTS'] =  "0"



import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

## Librerías
import seaborn as sns
import sys
import cv2 as cv2
import glob
from PIL import Image
import tensorflow as tf
import sys
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import gc
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
import os


from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import StandardScaler

print(tf.__version__)
# Out:
# 2024-09-20 17:49:42.859832: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-20 17:49:42.859880: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-20 17:49:42.865815: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-20 17:49:43.295006: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.14.0

# %%
## Uso de GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# 2024-09-20 17:49:47.619050: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-20 17:49:47.700733: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-20 17:49:47.700947: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# # Dataset

# %%
## function to load images
def load_binary_images(file_names):  
    image = np.load(file_names).astype(np.float32)
    image = np.expand_dims(image, axis=-1)
    image = tf.convert_to_tensor(image, dtype=tf.float32)
    image = tf.image.resize(image, [32,32])   
    ## binariazar
    image = tf.where(image > 0.1, 1.0, 0.0)  
    return image

def load_images(file_names):
    image = np.load(file_names).astype(np.float32)
    #expand_dims
    image = np.expand_dims(image, axis=-1)
    image = tf.convert_to_tensor(image, dtype=tf.float32)
    image = tf.image.resize(image, [32,32])/255.0    
      
    return image

def min_max_scaler(ruta,image):
    ## load images in the path
    images = glob.glob(ruta + '/*.npy')
    images = sorted(images)
    ## load images
    images = [load_images(image) for image in images]
    ## min max scaler of thei image using the max and min of all images
    images = np.array(images)
    max_value = np.max(images)
    min_value = np.min(images)
    image = tf.math.abs((image - min_value)/(max_value - min_value))
    return image   

## Function to get contours and features
def get_contours_and_features(binary_map):
    #https://docs.opencv.org/4.x/d3/d05/tutorial_py_table_of_contents_contours.html
    #binary_map = cv2.cvtColor(binary_map, cv2.COLOR_BGR2GRAY)
    contours, hierarchy = cv2.findContours(binary_map, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    contours_features = []
    for contour in contours:
        error = 1e-5
        moments = cv2.moments(contour)
        cx = moments['m10'] / (moments['m00'] + error)
        cy = moments['m01'] / (moments['m00'] + error)
        center_of_mass = [cx, cy]
        x,y,w,h = cv2.boundingRect(contour)        
        rect_area = w*h
        features = {
            'bounding_box': (x,y,w,h),
            'area': cv2.contourArea(contour),
            'perimeter': cv2.arcLength(contour, True),       
            #'solidity': np.float32(cv2.contourArea(contour))/cv2.convexHull(contour),
            'equivalent_diameter': np.sqrt(4*cv2.contourArea(contour)/np.pi),            
            'moments': moments,
            'center_of_mass': center_of_mass,
            'contour': contour
        }
        contours_features.append(features)
        del features
    #plt.imshow(contours_map, cmap='gray')
    return contours_features

# function to get a determined property from a list of contours features (area by default)
def get_item(contour_features, key='area'):
    areas = []
    for contour_feature in contour_features:
        area =  contour_feature[key]
        areas.append(area)
    return areas

## function to get geometric_attributes
def get_geometric_atributes(binary_images):
    descriptors = []
    for binary_img in binary_images:
        ## Formato
        image = binary_img.numpy().astype(np.uint8)       
        
        ## Capturar contornos
        contour_features = get_contours_and_features(image)
        
        ## Calcular vector de áreas de poro (todos los poros)
        areas = get_item(contour_features, key='area')

        ## Calcular vector de perímetros de poro (todo los poros)
        pmtro = get_item(contour_features, key='perimeter')

        ## Calcular el diametro equivalente de los poros
        eq_diameter = get_item(contour_features, key='equivalent_diameter')                

        descriptor = [np.mean(areas), np.mean(pmtro),np.mean(eq_diameter)]
        
        descriptors.append(descriptor)
        
    
    return descriptors

## function to get the middle image route in the folder
def get_middle_image(folder_route):
    ## get list of images
    images = glob.glob(folder_route + '/*.npy')
    ## order images
    images = sorted(images)
    ## get index of middle image
    if len(images) == 0:
        indx = -1
        middle_image = 'empty'
    else:
        indx = len(images)//2
        middle_image = images[indx]   
    
    return middle_image

# %%
## annotations to get nodule_features
annotations_cvs_4R = pd.read_csv('/data/Datasets/Nodules_ISBI/meta_created_info_3d_3R.csv')
annotations_csv_3R = pd.read_csv('/data/Datasets/Nodules_ISBI/meta_created_info_3d_4R.csv')
annotations = pd.concat([annotations_cvs_4R, annotations_csv_3R], ignore_index=True)
## drop malignancy = 3
annotations = annotations[annotations['malignancy'] != 3]
annotations
# Out:
#      patient_id  nodule_no           folder  malignancy is_cancer  \
# 0            34          0  LICD-0034_NI000           2     False
# 1            45          2  LICD-0045_NI002           4      True
# 2            58          0  LICD-0058_NI000           5      True
# 3            72          0  LICD-0072_NI000           5      True
# 4            75          1  LICD-0075_NI001           5      True
# ..          ...        ...              ...         ...       ...
# 916        1007          0  LICD-1007_NI000           2     False
# 917        1011          0  LICD-1011_NI000           4      True
# 918        1011          1  LICD-1011_NI001           5      True
# 919        1011          2  LICD-1011_NI002           5      True
# 920        1012          0  LICD-1012_NI000           2     False
#
#      calcification  lobulation  texture  spiculation  subtlety  margin  \
# 0                6           1        5            1         5       5
# 1                6           4        5            4         4       4
# 2                6           3        5            5         5       4
# 3                6           3        4            4         5       3
# 4                6           3        5            5         5       4
# ..             ...         ...      ...          ...       ...     ...
# 916              6           1        5            1         3       4
# 917              6           1        4            4         5       4
# 918              6           3        5            2         5       4
# 919              6           3        5            3         5       3
# 920              6           1        5            1         4       4
#
#      intercept  slope
# 0      -1024.0    1.0
# 1      -1024.0    1.0
# 2      -1024.0    1.0
# 3      -1024.0    1.0
# 4      -1024.0    1.0
# ..         ...    ...
# 916    -1024.0    1.0
# 917    -1024.0    1.0
# 918    -1024.0    1.0
# 919    -1024.0    1.0
# 920    -1024.0    1.0
#
# [533 rows x 13 columns]

# %%
## ruta dataset
rutas_images_npy = glob.glob('/data/Datasets/Nodules_ISBI/images/*/*.npy')

## order list by folder
rutas_images_npy = sorted(rutas_images_npy)

## get list of folders
folders = [ruta.split('/')[-2] for ruta in rutas_images_npy]
folders = np.unique(folders)

## build dataframe
rutas_images = []
rutas_masks = []
areas = []
perimetros = []
diametros = []
calsifications = []
spiculations = []
lobulations = []
sphericities = []
textures = []
margins = []
subletys = []

## cancer or not
labels = []
    
for folder in folders:
    ruta = '/data/Datasets/Nodules_ISBI/images/' + folder
    ruta_masc = '/data/Datasets/Nodules_ISBI/masks/' + folder
    
    ## load middle image route
    image_route = get_middle_image(ruta)
    name_image = image_route.split('/')[-1]
    mask_route = ruta_masc + '/' + name_image       
    
    if image_route != 'empty':    
        ## get attributes
        image = load_images(image_route)
        ## min-max scaler
        image = min_max_scaler(ruta, image)
        ## binary image
        binary_image = load_binary_images(mask_route)   
        ## get features of the image            
        features = annotations[annotations['folder'] == folder]
        if features.shape[0] != 0:     
            ## append rutas
            geometric_attributes = get_geometric_atributes([binary_image])[0]
            rutas_images.append(image_route)
            rutas_masks.append(mask_route)
            
            ## append attributes
            areas.append(geometric_attributes[0])
            perimetros.append(geometric_attributes[1])
            diametros.append(geometric_attributes[2])    
            
            ## evaluar si son nan e iomprimir solo si los  
              
            malignancy = features['malignancy'].values[0]
            calsification = features['calcification'].values[0]
            spiculation = features['spiculation'].values[0]
            lobulation = features['lobulation'].values[0]
            texture = features['texture'].values[0]
            label = features['is_cancer'].values[0]
            margin = features['margin'].values[0]
            sublety = features['subtlety'].values[0]
            
            ## append featuresprint(features)
            calsifications.append(calsification)
            spiculations.append(spiculation)
            lobulations.append(lobulation)
            textures.append(texture)
            labels.append(label)
            margins.append(margin)
            subletys.append(sublety)


## build dataframe
df = pd.DataFrame()
df['ruta'] = rutas_images
df['mask'] = rutas_masks
df['area'] = areas
df['perimetro'] = perimetros
df['diametro'] = diametros
df['calsification'] = calsifications
df['spiculation'] = spiculations
df['lobulation'] = lobulations
df['texture'] = textures
df['margin'] = margins
df['sublety'] = subletys
df['label'] = labels

df
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#                                                   ruta  \
# 0    /data/Datasets/Nodules_ISBI/images/LICD-0001_N...
# 1    /data/Datasets/Nodules_ISBI/images/LICD-0003_N...
# 2    /data/Datasets/Nodules_ISBI/images/LICD-0003_N...
# 3    /data/Datasets/Nodules_ISBI/images/LICD-0003_N...
# 4    /data/Datasets/Nodules_ISBI/images/LICD-0004_N...
# ..                                                 ...
# 528  /data/Datasets/Nodules_ISBI/images/LICD-1007_N...
# 529  /data/Datasets/Nodules_ISBI/images/LICD-1011_N...
# 530  /data/Datasets/Nodules_ISBI/images/LICD-1011_N...
# 531  /data/Datasets/Nodules_ISBI/images/LICD-1011_N...
# 532  /data/Datasets/Nodules_ISBI/images/LICD-1012_N...
#
#                                                   mask   area  perimetro  \
# 0    /data/Datasets/Nodules_ISBI/masks/LICD-0001_NI...  138.5  50.870057
# 1    /data/Datasets/Nodules_ISBI/masks/LICD-0003_NI...   90.5  38.384776
# 2    /data/Datasets/Nodules_ISBI/masks/LICD-0003_NI...   48.5  27.899495
# 3    /data/Datasets/Nodules_ISBI/masks/LICD-0003_NI...   55.5  28.727922
# 4    /data/Datasets/Nodules_ISBI/masks/LICD-0004_NI...   13.0  14.828427
# ..                                                 ...    ...        ...
# 528  /data/Datasets/Nodules_ISBI/masks/LICD-1007_NI...   22.5  18.242641
# 529  /data/Datasets/Nodules_ISBI/masks/LICD-1011_NI...  127.5  45.213203
# 530  /data/Datasets/Nodules_ISBI/masks/LICD-1011_NI...   81.5  39.556349
# 531  /data/Datasets/Nodules_ISBI/masks/LICD-1011_NI...   90.0  36.627417
# 532  /data/Datasets/Nodules_ISBI/masks/LICD-1012_NI...   32.0  22.485281
#
#       diametro  calsification  spiculation  lobulation  texture  margin  \
# 0    13.279446              6            5           3        5       4
# 1    10.734439              6            3           2        4       3
# 2     7.858252              6            2           2        5       4
# 3     8.406235              6            1           1        5       5
# 4     4.068429              3            1           1        5       5
# ..         ...            ...          ...         ...      ...     ...
# 528   5.352372              6            1           1        5       4
# 529  12.741195              6            4           1        4       4
# 530  10.186708              6            2           3        5       4
# 531  10.704745              6            3           3        5       3
# 532   6.383076              6            1           1        5       4
#
#      sublety  label
# 0          5   True
# 1          5   True
# 2          4   True
# 3          4   True
# 4          3  False
# ..       ...    ...
# 528        3  False
# 529        5   True
# 530        5   True
# 531        5   True
# 532        4  False
#
# [533 rows x 12 columns]

# %% [markdown]
# ## Dataset

# %%
## shuffle data
df_train_1, df_test = train_test_split(df, test_size=0.2, random_state=42)

## validation split
val_pctg = 0.8
split_validation_index = int(df_train_1.shape[0]*val_pctg)
df_train = df_train_1.iloc[:split_validation_index]
df_validation = df_train_1.iloc[split_validation_index:]

print('---- Distribución de entrenamiento, validación y test para benignos y malignos ----')
print('Malignos: ')
print('Positive train shape: ', df_train[df_train['label'] == 'True'].shape[0])
print('Positive val shape: ', df_validation[df_validation['label'] == 'True'].shape[0])
print('Positive test shape: ', df_test[df_test['label'] == 'True'].shape[0])

print('Benignos: ')
print('Negative train shape: ', df_train[df_train['label'] == 'False'].shape[0])
print('Negative val shape: ', df_validation[df_validation['label'] == 'False'].shape[0])
print('Negative test shape: ', df_test[df_test['label'] == 'False'].shape[0])

## eliminar NaN
df_train = df_train.dropna()
df_test = df_test.dropna()
df_validation = df_validation.dropna()

## replace labels
df_train.loc[:, 'label'] = df_train['label'].replace({'True': 1, 'False': 0})
df_test.loc[:, 'label'] = df_test['label'].replace({'True': 1, 'False': 0})
df_validation.loc[:, 'label'] = df_validation['label'].replace({'True': 1, 'False': 0})

print('---- Dataset finales ----')
print('Train shape: ', df_train.shape[0])
print('Test shape: ', df_test.shape[0])
print('Validation shape: ', df_validation.shape[0])
# Out:
# ---- Distribución de entrenamiento, validación y test para benignos y malignos ----
# Malignos:
# Positive train shape:  227
# Positive val shape:  59
# Positive test shape:  73
# Benignos:
# Negative train shape:  113
# Negative val shape:  27
# Negative test shape:  34
# ---- Dataset finales ----
# Train shape:  339
# Test shape:  107
# Validation shape:  85

# %%
## plot 5 first images with mas on the df train dataset
plt.figure(figsize=(20,10))
for i in range(5):
    image = load_images(df_train['ruta'].values[i])    
    plt.subplot(1,10,i+1)
    plt.imshow(image, cmap='gray')   
    plt.title('Label: ' + str(df_train['label'].values[i]))

# %%
## create dataset function 
features_to_use = ['area','perimetro','lobulation', 'texture', 'spiculation', 'margin']


def create_train_dataset(batch,df):
    images_routes = df['ruta'].to_numpy()
    mask_routes = df['mask'].to_numpy()
    labels = df['label'].to_numpy()
    features = df[features_to_use].to_numpy()
    
    
    ## Data augmentation    
    def rotate90_image(image):
        ## rotate 90 degrees
        image = tf.image.rot90(image)
        return image
    
    def rotate180_image(arg):
        ## rotate 180 degrees
        image = tf.image.rot90(arg, k=2)
        return image
    
    def rotate270_image(arg):
        ## rotate 270 degrees
        image = tf.image.rot90(arg, k=3)
        return image
    
    images = []
    mask = []
    new_labels = []
    new_features = []
    for image_route, mask_route, label, features in zip(images_routes,mask_routes, labels,features):
        ## imagenes y mascaras originales
        image_original = load_images(image_route)
        mask_original = load_binary_images(mask_route)
        
        ## augmentaciones
        # imagen original
        #image_left_flip = flip_left_image(image_original)
        image_rotate90 = rotate90_image(image_original)
        image_rotate180 = rotate180_image(image_original)
        image_rotate270 = rotate270_image(image_original)
        #image_up_flip = flip_up_image(image_original)
        ## mascara original
        #mask_left_flip = flip_left_image(mask_original)
        mask_rotate90 = rotate90_image(mask_original)
        mask_rotate180 = rotate180_image(mask_original)
        mask_rotate270 = rotate270_image(mask_original)
        #mask_up_flip = flip_up_image(mask_original)
        
        ## append image augmentation
        images.append(image_original)        
        images.append(image_rotate90)
        images.append(image_rotate180)
        images.append(image_rotate270)
        
        
        ## append mask augmentation
        mask.append(mask_original)        
        mask.append(mask_rotate90)
        mask.append(mask_rotate180)
        mask.append(mask_rotate270)
        
        ## append labels        
        new_labels.append(label)
        new_labels.append(label)
        new_labels.append(label)
        new_labels.append(label)           
        
        ## append features  
        new_features.append(features)
        new_features.append(features)
        new_features.append(features)
        new_features.append(features)
        
        
        
        
    ## convert to tensor
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    masks = tf.convert_to_tensor(mask, dtype=tf.float32)
    labels = tf.convert_to_tensor(new_labels, dtype=tf.float32)
    features = tf.convert_to_tensor(new_features, dtype=tf.float32)    
    
    
    dataset = tf.data.Dataset.from_tensor_slices((images, masks, features, labels))
    
    ## shuffle data
    dataset = dataset.shuffle(buffer_size=1000,seed=42)
    
    ## apply preprocess_image function
    dataset = dataset.map(lambda image, mask, features, label: (image, mask, features, label))
    
    dataset = dataset.batch(batch)
    
    return dataset


## create dataset function 
def create_test_dataset(batch,df):       
    images_routes = df['ruta'].to_numpy()
    mask_routes = df['mask'].to_numpy()
    labels = df['label'].to_numpy()
    features = df[features_to_use].to_numpy()
    
    
    images = []
    for image_route in images_routes:
        image = load_images(image_route)
        images.append(image)
        
    masks = []
    for mask_route in mask_routes:
        mask = load_binary_images(mask_route)
        masks.append(mask)
        
    ## convert to tensor
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    masks = tf.convert_to_tensor(mask, dtype=tf.float32)
    labels = tf.convert_to_tensor(labels, dtype=tf.float32)
    features = tf.convert_to_tensor(features, dtype=tf.float32)    
    
    dataset = tf.data.Dataset.from_tensor_slices((images, masks, features, labels))
    
    ## apply preprocess_image function
    dataset = dataset.map(lambda image, masks, features, label: (image, masks, features, label))
      
    dataset.batch(batch)
    
    return dataset

## both-clases
train_dataset = create_train_dataset(8, df_train)


for image, mask, features, label in train_dataset:
    print(image.shape)
    print(mask.shape)
    print(features.shape)
    print(label.shape)    
    break

i = 0 
for image, mask, features, label in train_dataset:
    i += np.shape(image)[0]   

print('Total de imagenes en el dataset de entrenamiento:', i)
# Out:
# (8, 32, 32, 1)
# (8, 32, 32, 1)
# (8, 6)
# (8,)
# Total de imagenes en el dataset de entrenamiento: 1356

# %%
for image, mask, features, label in train_dataset:
    ## plot 8 batch images and their mask
    plt.figure(figsize=(20,20))
    for i in range(8):
        plt.subplot(8,2,2*i+1)
        plt.imshow(image[i], cmap='gray')       
        plt.title('Image')
        plt.subplot(8,2,2*i+2)
        plt.imshow(mask[i], cmap='gray')
        plt.title('Mask')
        
    plt.tight_layout()
    plt.show()
    break

# %% [markdown]
# # Unet

# %%
## Encoder
nfilters = 16
latent_dim_vae = 32
number_of_features = len(features_to_use)
nx , ny = 32, 32


encoder_input = keras.Input(shape=(nx,ny,1), name='original_img')
encoder_features_input = keras.Input(shape=(number_of_features,), name='features')

c1 = layers.Conv2D(nfilters*1, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(encoder_input)
c1 = layers.BatchNormalization()(c1)
c1 = layers.Activation('relu')(c1)
p1 = layers.MaxPooling2D((2,2))(c1)
p1 = layers.Dropout(0.1)(p1)

c2 = layers.Conv2D(nfilters*2, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(p1)
c2 = layers.BatchNormalization()(c2)
c2 = layers.Activation('relu')(c2)
p2 = layers.MaxPooling2D((2,2))(c2)

c3 = layers.Conv2D(nfilters*4, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(p2)
c3 = layers.BatchNormalization()(c3)
c3 = layers.Activation('relu')(c3)
p3 = layers.MaxPooling2D((2,2))(c3)
p3 = layers.Dropout(0.1)(p3)

c4 = layers.Conv2D(nfilters*8, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(p3)
c4 = layers.BatchNormalization()(c4)
c4 = layers.Activation('relu')(c4)
p4 = layers.MaxPooling2D((2,2))(c4)
p4 = layers.Dropout(0.1)(p4)

c5 = layers.Conv2D(nfilters*16, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(p4)


x = layers.Dense(nfilters*16, activation='relu')(encoder_features_input)
x = layers.Dropout(0.1)(x)
x = layers.Dense(c5.shape[1] * c5.shape[2] * c5.shape[3], activation='relu')(x)
x = layers.Reshape((c5.shape[1], c5.shape[2], c5.shape[3]))(x)

combined_embbeding = layers.Concatenate()([c5, x])

## flatten combined embbeding
combined_embbeding = layers.Flatten()(combined_embbeding)

encoder_unet = keras.Model([encoder_input,encoder_features_input], [combined_embbeding , [c1,c2,c3,c4]], name='encoder')
encoder_unet.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  original_img (InputLayer)   [(None, 32, 32, 1)]          0         []
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 16)           160       ['original_img[0][0]']
#
#  batch_normalization_24 (Ba  (None, 32, 32, 16)           64        ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  max_pooling2d_20 (MaxPooli  (None, 16, 16, 16)           0         ['activation_24[0][0]']
#  ng2D)
#
#  dropout_22 (Dropout)        (None, 16, 16, 16)           0         ['max_pooling2d_20[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 32)           4640      ['dropout_22[0][0]']
#
#  batch_normalization_25 (Ba  (None, 16, 16, 32)           128       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 16, 16, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  max_pooling2d_21 (MaxPooli  (None, 8, 8, 32)             0         ['activation_25[0][0]']
#  ng2D)
#
#  conv2d_31 (Conv2D)          (None, 8, 8, 64)             18496     ['max_pooling2d_21[0][0]']
#
#  batch_normalization_26 (Ba  (None, 8, 8, 64)             256       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  max_pooling2d_22 (MaxPooli  (None, 4, 4, 64)             0         ['activation_26[0][0]']
#  ng2D)
#
#  dropout_23 (Dropout)        (None, 4, 4, 64)             0         ['max_pooling2d_22[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 4, 4, 128)            73856     ['dropout_23[0][0]']
#
#  batch_normalization_27 (Ba  (None, 4, 4, 128)            512       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  features (InputLayer)       [(None, 6)]                  0         []
#
#  activation_27 (Activation)  (None, 4, 4, 128)            0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  dense_8 (Dense)             (None, 256)                  1792      ['features[0][0]']
#
#  max_pooling2d_23 (MaxPooli  (None, 2, 2, 128)            0         ['activation_27[0][0]']
#  ng2D)
#
#  dropout_25 (Dropout)        (None, 256)                  0         ['dense_8[0][0]']
#
#  dropout_24 (Dropout)        (None, 2, 2, 128)            0         ['max_pooling2d_23[0][0]']
#
#  dense_9 (Dense)             (None, 1024)                 263168    ['dropout_25[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 2, 2, 256)            295168    ['dropout_24[0][0]']
#
#  reshape_5 (Reshape)         (None, 2, 2, 256)            0         ['dense_9[0][0]']
#
#  concatenate_8 (Concatenate  (None, 2, 2, 512)            0         ['conv2d_33[0][0]',
#  )                                                                   'reshape_5[0][0]']
#
#  flatten_4 (Flatten)         (None, 2048)                 0         ['concatenate_8[0][0]']
#
# ==================================================================================================
# Total params: 658240 (2.51 MB)
# Trainable params: 657760 (2.51 MB)
# Non-trainable params: 480 (1.88 KB)
# __________________________________________________________________________________________________

# %%
## decoder 
decoder_input = keras.Input(shape=combined_embbeding.shape[1] + latent_dim_vae, name='encoded_img')
c1_dec = keras.Input(shape=c1.shape[1:], name='c1_input')
c2_dec = keras.Input(shape=c2.shape[1:], name='c2_input')
c3_dec = keras.Input(shape=c3.shape[1:], name='c3_input')
c4_dec = keras.Input(shape=c4.shape[1:], name='c4_input')

## reshape decoder input
x = layers.Dense(2*2*nfilters*16, activation='relu')(decoder_input)
x = layers.Reshape((2,2,nfilters*16))(x)

## decoder layers from embedding
u1_dec = layers.Conv2DTranspose(nfilters*8, (2,2), strides=(2,2), padding='same')(x)
u1_dec = layers.concatenate([u1_dec, c4_dec])
u1_dec = layers.Dropout(0.1)(u1_dec)
c6_dec = layers.Conv2D(nfilters*16, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(u1_dec)
c6_dec = layers.BatchNormalization()(u1_dec)
c6_dec = layers.Activation('relu')(u1_dec)

u2_dec = layers.Conv2DTranspose(nfilters*8, (2,2), strides=(2,2), padding='same')(c6_dec)
u2_dec = layers.concatenate([u2_dec, c3_dec])
u2_dec = layers.Dropout(0.1)(u2_dec)
c7_dec = layers.Conv2D(nfilters*8, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(u2_dec)
c7_dec = layers.BatchNormalization()(u2_dec)
c7_dec = layers.Activation('relu')(u2_dec)

u3_dec = layers.Conv2DTranspose(nfilters*4, (2,2), strides=(2,2), padding='same')(c7_dec)
u3_dec = layers.concatenate([u3_dec, c2_dec])
u3_dec = layers.Dropout(0.1)(u3_dec)
c8_dec = layers.Conv2D(nfilters*4, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(u3_dec)
c8_dec = layers.BatchNormalization()(u3_dec)
c8_dec = layers.Activation('relu')(u3_dec)

u4_dec = layers.Conv2DTranspose(nfilters*2, (2,2), strides=(2,2), padding='same')(c8_dec)
u4_dec = layers.concatenate([u4_dec, c1_dec])
u4_dec = layers.Dropout(0.1)(u4_dec)
c9_dec = layers.Conv2D(nfilters*2, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(u4_dec)
c9_dec = layers.BatchNormalization()(u4_dec)
c9_dec = layers.Activation('relu')(u4_dec)


segmentation_output = layers.Conv2D(1, (1,1), activation='sigmoid', name='segmentation')(c9_dec)

## decoder model
decoder_unet = keras.Model([decoder_input, c1_dec, c2_dec, c3_dec, c4_dec], segmentation_output, name='decoder')
decoder_unet.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  encoded_img (InputLayer)    [(None, 2080)]               0         []
#
#  dense_10 (Dense)            (None, 1024)                 2130944   ['encoded_img[0][0]']
#
#  reshape_6 (Reshape)         (None, 2, 2, 256)            0         ['dense_10[0][0]']
#
#  conv2d_transpose_10 (Conv2  (None, 4, 4, 128)            131200    ['reshape_6[0][0]']
#  DTranspose)
#
#  c4_input (InputLayer)       [(None, 4, 4, 128)]          0         []
#
#  concatenate_9 (Concatenate  (None, 4, 4, 256)            0         ['conv2d_transpose_10[0][0]',
#  )                                                                   'c4_input[0][0]']
#
#  dropout_26 (Dropout)        (None, 4, 4, 256)            0         ['concatenate_9[0][0]']
#
#  activation_28 (Activation)  (None, 4, 4, 256)            0         ['dropout_26[0][0]']
#
#  conv2d_transpose_11 (Conv2  (None, 8, 8, 128)            131200    ['activation_28[0][0]']
#  DTranspose)
#
#  c3_input (InputLayer)       [(None, 8, 8, 64)]           0         []
#
#  concatenate_10 (Concatenat  (None, 8, 8, 192)            0         ['conv2d_transpose_11[0][0]',
#  e)                                                                  'c3_input[0][0]']
#
#  dropout_27 (Dropout)        (None, 8, 8, 192)            0         ['concatenate_10[0][0]']
#
#  activation_29 (Activation)  (None, 8, 8, 192)            0         ['dropout_27[0][0]']
#
#  conv2d_transpose_12 (Conv2  (None, 16, 16, 64)           49216     ['activation_29[0][0]']
#  DTranspose)
#
#  c2_input (InputLayer)       [(None, 16, 16, 32)]         0         []
#
#  concatenate_11 (Concatenat  (None, 16, 16, 96)           0         ['conv2d_transpose_12[0][0]',
#  e)                                                                  'c2_input[0][0]']
#
#  dropout_28 (Dropout)        (None, 16, 16, 96)           0         ['concatenate_11[0][0]']
#
#  activation_30 (Activation)  (None, 16, 16, 96)           0         ['dropout_28[0][0]']
#
#  conv2d_transpose_13 (Conv2  (None, 32, 32, 32)           12320     ['activation_30[0][0]']
#  DTranspose)
#
#  c1_input (InputLayer)       [(None, 32, 32, 16)]         0         []
#
#  concatenate_12 (Concatenat  (None, 32, 32, 48)           0         ['conv2d_transpose_13[0][0]',
#  e)                                                                  'c1_input[0][0]']
#
#  dropout_29 (Dropout)        (None, 32, 32, 48)           0         ['concatenate_12[0][0]']
#
#  activation_31 (Activation)  (None, 32, 32, 48)           0         ['dropout_29[0][0]']
#
#  segmentation (Conv2D)       (None, 32, 32, 1)            49        ['activation_31[0][0]']
#
# ==================================================================================================
# Total params: 2454929 (9.36 MB)
# Trainable params: 2454929 (9.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # VAE

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
## encoder
encoder_input = keras.Input(shape=(nx,ny,1), name='original_img')

c1 = layers.Conv2D(nfilters*1, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(encoder_input)
c1 = layers.BatchNormalization()(c1)
c1 = layers.Activation('relu')(c1)
p1 = layers.MaxPooling2D((2,2))(c1)
p1 = layers.Dropout(0.1)(p1)

c2 = layers.Conv2D(nfilters*2, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(p1)
c2 = layers.BatchNormalization()(c2)
c2 = layers.Activation('relu')(c2)
p2 = layers.MaxPooling2D((2,2))(c2)

c3 = layers.Conv2D(nfilters*4, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(p2)
c3 = layers.BatchNormalization()(c3)
c3 = layers.Activation('relu')(c3)
p3 = layers.MaxPooling2D((2,2))(c3)
p3 = layers.Dropout(0.1)(p3)

c4 = layers.Conv2D(nfilters*8, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(p3)
c4 = layers.BatchNormalization()(c4)
c4 = layers.Activation('relu')(c4)
p4 = layers.MaxPooling2D((2,2))(c4)
p4 = layers.Dropout(0.1)(p4)

c5 = layers.Conv2D(nfilters*16, kernel_size=(3,3),
               kernel_initializer='he_normal', padding='same')(p4)

# Flatten and Embedding
c5_flatten = layers.Flatten()(c5)
x = layers.Dense(latent_dim_vae, name='embedding')(c5_flatten)

z_mean = layers.Dense(latent_dim_vae, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim_vae, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])

encoder_vae = keras.Model(inputs=encoder_input , outputs=[z_mean, z_log_var, z], name="encoder")
encoder_vae.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  original_img (InputLayer)   [(None, 32, 32, 1)]          0         []
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 16)           160       ['original_img[0][0]']
#
#  batch_normalization_32 (Ba  (None, 32, 32, 16)           64        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  max_pooling2d_24 (MaxPooli  (None, 16, 16, 16)           0         ['activation_32[0][0]']
#  ng2D)
#
#  dropout_30 (Dropout)        (None, 16, 16, 16)           0         ['max_pooling2d_24[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 32)           4640      ['dropout_30[0][0]']
#
#  batch_normalization_33 (Ba  (None, 16, 16, 32)           128       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 16, 16, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  max_pooling2d_25 (MaxPooli  (None, 8, 8, 32)             0         ['activation_33[0][0]']
#  ng2D)
#
#  conv2d_40 (Conv2D)          (None, 8, 8, 64)             18496     ['max_pooling2d_25[0][0]']
#
#  batch_normalization_34 (Ba  (None, 8, 8, 64)             256       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  max_pooling2d_26 (MaxPooli  (None, 4, 4, 64)             0         ['activation_34[0][0]']
#  ng2D)
#
#  dropout_31 (Dropout)        (None, 4, 4, 64)             0         ['max_pooling2d_26[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 4, 4, 128)            73856     ['dropout_31[0][0]']
#
#  batch_normalization_35 (Ba  (None, 4, 4, 128)            512       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 4, 4, 128)            0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  max_pooling2d_27 (MaxPooli  (None, 2, 2, 128)            0         ['activation_35[0][0]']
#  ng2D)
#
#  dropout_32 (Dropout)        (None, 2, 2, 128)            0         ['max_pooling2d_27[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 2, 2, 256)            295168    ['dropout_32[0][0]']
#
#  flatten_5 (Flatten)         (None, 1024)                 0         ['conv2d_42[0][0]']
#
#  embedding (Dense)           (None, 32)                   32800     ['flatten_5[0][0]']
#
#  z_mean (Dense)              (None, 32)                   1056      ['embedding[0][0]']
#
#  z_log_var (Dense)           (None, 32)                   1056      ['embedding[0][0]']
#
#  sampling_1 (Sampling)       (None, 32)                   0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 428192 (1.63 MB)
# Trainable params: 427712 (1.63 MB)
# Non-trainable params: 480 (1.88 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Modelo

# %%
class Unet_VAE_features(keras.Model):
    def __init__(self, unet_encoder, unet_decoder,vae_encoder, **kwargs):
        super(Unet_VAE_features, self).__init__()
        self.encoder_unet = unet_encoder
        self.encoder_vae = vae_encoder
        self.decoder_unet = unet_decoder
        
        ## loss
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.segmentation_loss_tracker = keras.metrics.Mean(name="segmentation_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        
    @property
    def metrics(self):
        return [self.total_loss_tracker, 
                self.segmentation_loss_tracker,
                self.kl_loss_tracker,
                ]
    
    def train_step(self, data):
        image, mask, features, label = data
        with tf.GradientTape() as tape:
            embedding, activations = self.encoder_unet([image,features], training=True)
            z_mean, z_log_var, z = self.encoder_vae(image, training=True)
            ## concatenate
            embedding = tf.concat([embedding, z], axis=1)
            ## segmentaciones
            reconstruction = self.decoder_unet([embedding] + activations, training=True)
            
            ## perdida de segmentación            
            reconstruction_loss = tf.reduce_mean(keras.losses.binary_crossentropy(mask, reconstruction))
            
            ## perdida de kl
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))            
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))  
                                
            total_loss = reconstruction_loss + kl_loss             
            
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.segmentation_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        
        return {"total_loss": self.total_loss_tracker.result(), 
                "segmentation_loss": self.segmentation_loss_tracker.result(),
                "kl_loss": self.kl_loss_tracker.result()}

# %%
learning_rate = 0.001
epochs = 2000
batch = 8
patience = 15

unet_vae_model = Unet_VAE_features(encoder_unet, decoder_unet, encoder_vae)
opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)
unet_vae_model .compile(optimizer=opt)

unet_vae_model .fit(train_dataset, epochs=epochs, 
                batch_size=batch,
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='total_loss', patience=30)])
# Out:
# Epoch 1/2000
# 2024-09-20 04:55:12.934114: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inencoder/dropout_22/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-09-20 04:55:13.554322: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 2024-09-20 04:55:16.222726: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fb00c0866f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-09-20 04:55:16.222751: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-09-20 04:55:16.284121: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-20 04:55:16.474078: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 170/170 [==============================] - 13s 17ms/step - total_loss: 59.6707 - segmentation_loss: 0.0731 - kl_loss: 59.5976
# Epoch 2/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 7.4176 - segmentation_loss: 0.0350 - kl_loss: 7.3826
# Epoch 3/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 4.2870 - segmentation_loss: 0.0316 - kl_loss: 4.2554
# Epoch 4/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 2.8169 - segmentation_loss: 0.0290 - kl_loss: 2.7879
# Epoch 5/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 1.9006 - segmentation_loss: 0.0280 - kl_loss: 1.8726
# Epoch 6/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 1.4020 - segmentation_loss: 0.0268 - kl_loss: 1.3751
# Epoch 7/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 1.0424 - segmentation_loss: 0.0260 - kl_loss: 1.0163
# Epoch 8/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.8008 - segmentation_loss: 0.0251 - kl_loss: 0.7757
# Epoch 9/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.6265 - segmentation_loss: 0.0246 - kl_loss: 0.6019
# Epoch 10/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.5049 - segmentation_loss: 0.0239 - kl_loss: 0.4809
# Epoch 11/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.4169 - segmentation_loss: 0.0237 - kl_loss: 0.3932
# Epoch 12/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.3403 - segmentation_loss: 0.0236 - kl_loss: 0.3167
# Epoch 13/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.2783 - segmentation_loss: 0.0227 - kl_loss: 0.2556
# Epoch 14/2000
# 170/170 [==============================] - 2s 12ms/step - total_loss: 0.2385 - segmentation_loss: 0.0228 - kl_loss: 0.2157
# Epoch 15/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.1991 - segmentation_loss: 0.0222 - kl_loss: 0.1769
# Epoch 16/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.1704 - segmentation_loss: 0.0216 - kl_loss: 0.1489
# Epoch 17/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.1454 - segmentation_loss: 0.0209 - kl_loss: 0.1245
# Epoch 18/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.1256 - segmentation_loss: 0.0204 - kl_loss: 0.1051
# Epoch 19/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.1113 - segmentation_loss: 0.0205 - kl_loss: 0.0909
# Epoch 20/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0990 - segmentation_loss: 0.0199 - kl_loss: 0.0792
# Epoch 21/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0874 - segmentation_loss: 0.0198 - kl_loss: 0.0677
# Epoch 22/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0795 - segmentation_loss: 0.0197 - kl_loss: 0.0597
# Epoch 23/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0719 - segmentation_loss: 0.0191 - kl_loss: 0.0527
# Epoch 24/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0629 - segmentation_loss: 0.0188 - kl_loss: 0.0441
# Epoch 25/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0617 - segmentation_loss: 0.0184 - kl_loss: 0.0434
# Epoch 26/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0633 - segmentation_loss: 0.0182 - kl_loss: 0.0451
# Epoch 27/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.1233 - segmentation_loss: 0.0182 - kl_loss: 0.1051
# Epoch 28/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.1887 - segmentation_loss: 0.0177 - kl_loss: 0.1710
# Epoch 29/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0962 - segmentation_loss: 0.0172 - kl_loss: 0.0789
# Epoch 30/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0694 - segmentation_loss: 0.0173 - kl_loss: 0.0521
# Epoch 31/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.1035 - segmentation_loss: 0.0170 - kl_loss: 0.0865
# Epoch 32/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.1409 - segmentation_loss: 0.0168 - kl_loss: 0.1241
# Epoch 33/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0645 - segmentation_loss: 0.0166 - kl_loss: 0.0479
# Epoch 34/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0463 - segmentation_loss: 0.0164 - kl_loss: 0.0300
# Epoch 35/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0504 - segmentation_loss: 0.0164 - kl_loss: 0.0340
# Epoch 36/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0666 - segmentation_loss: 0.0160 - kl_loss: 0.0505
# Epoch 37/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0547 - segmentation_loss: 0.0157 - kl_loss: 0.0390
# Epoch 38/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0590 - segmentation_loss: 0.0155 - kl_loss: 0.0436
# Epoch 39/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.1259 - segmentation_loss: 0.0153 - kl_loss: 0.1106
# Epoch 40/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0695 - segmentation_loss: 0.0163 - kl_loss: 0.0532
# Epoch 41/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0708 - segmentation_loss: 0.0157 - kl_loss: 0.0551
# Epoch 42/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0345 - segmentation_loss: 0.0147 - kl_loss: 0.0198
# Epoch 43/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0382 - segmentation_loss: 0.0144 - kl_loss: 0.0238
# Epoch 44/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0436 - segmentation_loss: 0.0144 - kl_loss: 0.0292
# Epoch 45/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0402 - segmentation_loss: 0.0147 - kl_loss: 0.0255
# Epoch 46/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0519 - segmentation_loss: 0.0138 - kl_loss: 0.0382
# Epoch 47/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0456 - segmentation_loss: 0.0138 - kl_loss: 0.0318
# Epoch 48/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0614 - segmentation_loss: 0.0135 - kl_loss: 0.0479
# Epoch 49/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0449 - segmentation_loss: 0.0136 - kl_loss: 0.0313
# Epoch 50/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0434 - segmentation_loss: 0.0136 - kl_loss: 0.0298
# Epoch 51/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0371 - segmentation_loss: 0.0147 - kl_loss: 0.0225
# Epoch 52/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0319 - segmentation_loss: 0.0131 - kl_loss: 0.0188
# Epoch 53/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0224 - segmentation_loss: 0.0128 - kl_loss: 0.0096
# Epoch 54/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0199 - segmentation_loss: 0.0132 - kl_loss: 0.0067
# Epoch 55/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0179 - segmentation_loss: 0.0126 - kl_loss: 0.0053
# Epoch 56/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0213 - segmentation_loss: 0.0127 - kl_loss: 0.0086
# Epoch 57/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0213 - segmentation_loss: 0.0122 - kl_loss: 0.0090
# Epoch 58/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0318 - segmentation_loss: 0.0125 - kl_loss: 0.0192
# Epoch 59/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0215 - segmentation_loss: 0.0121 - kl_loss: 0.0094
# Epoch 60/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0309 - segmentation_loss: 0.0120 - kl_loss: 0.0190
# Epoch 61/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0213 - segmentation_loss: 0.0119 - kl_loss: 0.0094
# Epoch 62/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0169 - segmentation_loss: 0.0116 - kl_loss: 0.0053
# Epoch 63/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0187 - segmentation_loss: 0.0118 - kl_loss: 0.0070
# Epoch 64/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0164 - segmentation_loss: 0.0122 - kl_loss: 0.0042
# Epoch 65/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0182 - segmentation_loss: 0.0118 - kl_loss: 0.0064
# Epoch 66/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0155 - segmentation_loss: 0.0114 - kl_loss: 0.0041
# Epoch 67/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0144 - segmentation_loss: 0.0111 - kl_loss: 0.0033
# Epoch 68/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0191 - segmentation_loss: 0.0112 - kl_loss: 0.0079
# Epoch 69/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0139 - segmentation_loss: 0.0109 - kl_loss: 0.0030
# Epoch 70/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0154 - segmentation_loss: 0.0110 - kl_loss: 0.0044
# Epoch 71/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0238 - segmentation_loss: 0.0111 - kl_loss: 0.0128
# Epoch 72/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0164 - segmentation_loss: 0.0109 - kl_loss: 0.0056
# Epoch 73/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0125 - segmentation_loss: 0.0106 - kl_loss: 0.0019
# Epoch 74/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0117 - segmentation_loss: 0.0107 - kl_loss: 0.0010
# Epoch 75/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0114 - segmentation_loss: 0.0106 - kl_loss: 8.0893e-04
# Epoch 76/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0114 - segmentation_loss: 0.0103 - kl_loss: 0.0011
# Epoch 77/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0110 - segmentation_loss: 0.0102 - kl_loss: 8.7186e-04
# Epoch 78/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0126 - segmentation_loss: 0.0102 - kl_loss: 0.0024
# Epoch 79/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0115 - segmentation_loss: 0.0102 - kl_loss: 0.0013
# Epoch 80/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0110 - segmentation_loss: 0.0102 - kl_loss: 8.3276e-04
# Epoch 81/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0113 - segmentation_loss: 0.0100 - kl_loss: 0.0013
# Epoch 82/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0129 - segmentation_loss: 0.0099 - kl_loss: 0.0030
# Epoch 83/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0103 - segmentation_loss: 0.0096 - kl_loss: 7.0595e-04
# Epoch 84/2000
# 170/170 [==============================] - 2s 12ms/step - total_loss: 0.0129 - segmentation_loss: 0.0096 - kl_loss: 0.0032
# Epoch 85/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0104 - segmentation_loss: 0.0100 - kl_loss: 4.1248e-04
# Epoch 86/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0099 - segmentation_loss: 0.0097 - kl_loss: 1.3254e-04
# Epoch 87/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0097 - segmentation_loss: 0.0096 - kl_loss: 8.1437e-05
# Epoch 88/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0096 - segmentation_loss: 0.0093 - kl_loss: 3.4399e-04
# Epoch 89/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0096 - segmentation_loss: 0.0095 - kl_loss: 9.5529e-05
# Epoch 90/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0124 - segmentation_loss: 0.0123 - kl_loss: 9.9413e-05
# Epoch 91/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0114 - segmentation_loss: 0.0107 - kl_loss: 7.1617e-04
# Epoch 92/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0098 - segmentation_loss: 0.0096 - kl_loss: 1.3258e-04
# Epoch 93/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0105 - segmentation_loss: 0.0093 - kl_loss: 0.0012
# Epoch 94/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0090 - segmentation_loss: 0.0090 - kl_loss: 9.1618e-05
# Epoch 95/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0089 - segmentation_loss: 0.0088 - kl_loss: 4.3219e-05
# Epoch 96/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0088 - segmentation_loss: 0.0087 - kl_loss: 2.4772e-05
# Epoch 97/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0088 - segmentation_loss: 0.0088 - kl_loss: 1.5303e-05
# Epoch 98/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0087 - segmentation_loss: 0.0087 - kl_loss: 3.3954e-05
# Epoch 99/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0085 - segmentation_loss: 0.0085 - kl_loss: 3.8932e-05
# Epoch 100/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0085 - segmentation_loss: 0.0084 - kl_loss: 1.1195e-04
# Epoch 101/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0084 - segmentation_loss: 0.0084 - kl_loss: 2.1626e-05
# Epoch 102/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0087 - segmentation_loss: 0.0087 - kl_loss: 3.0410e-05
# Epoch 103/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0084 - segmentation_loss: 0.0084 - kl_loss: 1.1681e-05
# Epoch 104/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0086 - segmentation_loss: 0.0086 - kl_loss: 9.7755e-06
# Epoch 105/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0084 - segmentation_loss: 0.0084 - kl_loss: 9.1566e-06
# Epoch 106/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0083 - segmentation_loss: 0.0082 - kl_loss: 1.1307e-04
# Epoch 107/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0084 - segmentation_loss: 0.0080 - kl_loss: 4.0715e-04
# Epoch 108/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0082 - segmentation_loss: 0.0081 - kl_loss: 1.0917e-04
# Epoch 109/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0083 - segmentation_loss: 0.0083 - kl_loss: 4.3251e-05
# Epoch 110/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0080 - segmentation_loss: 0.0080 - kl_loss: 1.6931e-05
# Epoch 111/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0085 - segmentation_loss: 0.0085 - kl_loss: 7.2925e-06
# Epoch 112/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0084 - segmentation_loss: 0.0084 - kl_loss: 4.8020e-06
# Epoch 113/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0081 - segmentation_loss: 0.0081 - kl_loss: 4.8942e-06
# Epoch 114/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0081 - segmentation_loss: 0.0081 - kl_loss: 1.8095e-05
# Epoch 115/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0087 - segmentation_loss: 0.0087 - kl_loss: 1.1953e-05
# Epoch 116/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0079 - segmentation_loss: 0.0079 - kl_loss: 1.8282e-05
# Epoch 117/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0078 - segmentation_loss: 0.0078 - kl_loss: 5.7073e-06
# Epoch 118/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0078 - segmentation_loss: 0.0078 - kl_loss: 1.6457e-06
# Epoch 119/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0077 - segmentation_loss: 0.0077 - kl_loss: 2.3770e-06
# Epoch 120/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0077 - segmentation_loss: 0.0077 - kl_loss: 1.0260e-06
# Epoch 121/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0075 - segmentation_loss: 0.0075 - kl_loss: 1.8811e-06
# Epoch 122/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0077 - segmentation_loss: 0.0077 - kl_loss: 1.2037e-06
# Epoch 123/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0078 - segmentation_loss: 0.0078 - kl_loss: 1.4322e-05
# Epoch 124/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0080 - segmentation_loss: 0.0080 - kl_loss: 2.9539e-05
# Epoch 125/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0077 - segmentation_loss: 0.0077 - kl_loss: 3.6715e-05
# Epoch 126/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0077 - segmentation_loss: 0.0074 - kl_loss: 2.3394e-04
# Epoch 127/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0077 - segmentation_loss: 0.0077 - kl_loss: 8.6432e-06
# Epoch 128/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0077 - segmentation_loss: 0.0074 - kl_loss: 2.3905e-04
# Epoch 129/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0072 - segmentation_loss: 0.0072 - kl_loss: 4.0390e-06
# Epoch 130/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0072 - segmentation_loss: 0.0072 - kl_loss: 2.1692e-06
# Epoch 131/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0071 - segmentation_loss: 0.0071 - kl_loss: 8.7912e-07
# Epoch 132/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0073 - segmentation_loss: 0.0073 - kl_loss: 5.8009e-07
# Epoch 133/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0071 - segmentation_loss: 0.0071 - kl_loss: 5.6026e-07
# Epoch 134/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0074 - segmentation_loss: 0.0074 - kl_loss: 6.8896e-07
# Epoch 135/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0075 - segmentation_loss: 0.0075 - kl_loss: 2.4911e-07
# Epoch 136/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0077 - segmentation_loss: 0.0077 - kl_loss: 2.7725e-07
# Epoch 137/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0078 - segmentation_loss: 0.0078 - kl_loss: 2.1602e-06
# Epoch 138/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0073 - segmentation_loss: 0.0073 - kl_loss: 4.7724e-06
# Epoch 139/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0097 - segmentation_loss: 0.0078 - kl_loss: 0.0019
# Epoch 140/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0079 - segmentation_loss: 0.0079 - kl_loss: 2.7032e-05
# Epoch 141/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0075 - segmentation_loss: 0.0074 - kl_loss: 1.1954e-04
# Epoch 142/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0071 - segmentation_loss: 0.0069 - kl_loss: 1.5252e-04
# Epoch 143/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0069 - segmentation_loss: 0.0069 - kl_loss: 5.6392e-06
# Epoch 144/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0068 - segmentation_loss: 0.0068 - kl_loss: 1.2368e-06
# Epoch 145/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0067 - segmentation_loss: 0.0067 - kl_loss: 3.3173e-07
# Epoch 146/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0068 - segmentation_loss: 0.0068 - kl_loss: 5.4852e-07
# Epoch 147/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0067 - segmentation_loss: 0.0067 - kl_loss: 5.5673e-07
# Epoch 148/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0066 - segmentation_loss: 0.0066 - kl_loss: 1.8414e-07
# Epoch 149/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0068 - segmentation_loss: 0.0068 - kl_loss: 1.7366e-07
# Epoch 150/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0075 - segmentation_loss: 0.0075 - kl_loss: 4.4839e-07
# Epoch 151/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0078 - segmentation_loss: 0.0078 - kl_loss: 1.7643e-07
# Epoch 152/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0071 - segmentation_loss: 0.0071 - kl_loss: 3.5125e-07
# Epoch 153/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0065 - segmentation_loss: 0.0065 - kl_loss: 1.7141e-07
# Epoch 154/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0067 - segmentation_loss: 0.0067 - kl_loss: 2.2591e-07
# Epoch 155/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0063 - segmentation_loss: 0.0063 - kl_loss: 3.3153e-07
# Epoch 156/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0063 - segmentation_loss: 0.0063 - kl_loss: 1.8098e-07
# Epoch 157/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0064 - segmentation_loss: 0.0064 - kl_loss: 1.4901e-07
# Epoch 158/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0065 - segmentation_loss: 0.0065 - kl_loss: 1.8543e-07
# Epoch 159/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0063 - segmentation_loss: 0.0063 - kl_loss: 1.7675e-07
# Epoch 160/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0064 - segmentation_loss: 0.0064 - kl_loss: 1.4305e-07
# Epoch 161/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0063 - segmentation_loss: 0.0063 - kl_loss: 5.7192e-07
# Epoch 162/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0063 - segmentation_loss: 0.0063 - kl_loss: 1.5083e-07
# Epoch 163/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0064 - segmentation_loss: 0.0064 - kl_loss: 1.8569e-07
# Epoch 164/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0064 - segmentation_loss: 0.0064 - kl_loss: 1.9678e-07
# Epoch 165/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0083 - segmentation_loss: 0.0083 - kl_loss: 6.0527e-07
# Epoch 166/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0068 - segmentation_loss: 0.0068 - kl_loss: 1.9339e-07
# Epoch 167/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0064 - segmentation_loss: 0.0064 - kl_loss: 1.5427e-07
# Epoch 168/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0063 - segmentation_loss: 0.0063 - kl_loss: 1.5655e-07
# Epoch 169/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0063 - segmentation_loss: 0.0063 - kl_loss: 1.8344e-07
# Epoch 170/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0062 - segmentation_loss: 0.0062 - kl_loss: 2.0145e-07
# Epoch 171/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0061 - segmentation_loss: 0.0061 - kl_loss: 1.9083e-06
# Epoch 172/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0060 - segmentation_loss: 0.0060 - kl_loss: 1.7386e-06
# Epoch 173/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0061 - segmentation_loss: 0.0061 - kl_loss: 1.8162e-07
# Epoch 174/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0060 - segmentation_loss: 0.0060 - kl_loss: 2.9261e-07
# Epoch 175/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0067 - segmentation_loss: 0.0067 - kl_loss: 2.2273e-07
# Epoch 176/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0061 - segmentation_loss: 0.0061 - kl_loss: 1.7741e-07
# Epoch 177/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0058 - segmentation_loss: 0.0058 - kl_loss: 1.6624e-07
# Epoch 178/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0059 - segmentation_loss: 0.0059 - kl_loss: 1.9678e-07
# Epoch 179/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0058 - segmentation_loss: 0.0058 - kl_loss: 2.0371e-07
# Epoch 180/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0057 - segmentation_loss: 0.0057 - kl_loss: 1.9652e-07
# Epoch 181/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0061 - segmentation_loss: 0.0061 - kl_loss: 2.0756e-07
# Epoch 182/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0060 - segmentation_loss: 0.0060 - kl_loss: 2.0947e-07
# Epoch 183/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0059 - segmentation_loss: 0.0059 - kl_loss: 2.2457e-07
# Epoch 184/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0058 - segmentation_loss: 0.0058 - kl_loss: 2.9309e-07
# Epoch 185/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0060 - segmentation_loss: 0.0060 - kl_loss: 3.1387e-07
# Epoch 186/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0060 - segmentation_loss: 0.0060 - kl_loss: 2.2242e-07
# Epoch 187/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0059 - segmentation_loss: 0.0059 - kl_loss: 2.7032e-07
# Epoch 188/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 2.4789e-07
# Epoch 189/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 3.8892e-07
# Epoch 190/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0058 - segmentation_loss: 0.0058 - kl_loss: 2.1896e-07
# Epoch 191/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0061 - segmentation_loss: 0.0061 - kl_loss: 3.7919e-07
# Epoch 192/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0058 - segmentation_loss: 0.0058 - kl_loss: 2.5080e-07
# Epoch 193/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0058 - segmentation_loss: 0.0058 - kl_loss: 2.5665e-07
# Epoch 194/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 2.6261e-07
# Epoch 195/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 2.5402e-07
# Epoch 196/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0058 - segmentation_loss: 0.0058 - kl_loss: 2.4718e-07
# Epoch 197/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0058 - segmentation_loss: 0.0058 - kl_loss: 2.8207e-07
# Epoch 198/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 2.3298e-07
# Epoch 199/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0057 - segmentation_loss: 0.0057 - kl_loss: 6.0632e-07
# Epoch 200/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0068 - segmentation_loss: 0.0068 - kl_loss: 2.9502e-06
# Epoch 201/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0060 - segmentation_loss: 0.0060 - kl_loss: 5.4192e-06
# Epoch 202/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 5.2895e-07
# Epoch 203/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0060 - segmentation_loss: 0.0060 - kl_loss: 2.2415e-07
# Epoch 204/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 1.9470e-07
# Epoch 205/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0055 - segmentation_loss: 0.0055 - kl_loss: 1.8861e-07
# Epoch 206/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0055 - segmentation_loss: 0.0055 - kl_loss: 1.9595e-07
# Epoch 207/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0055 - segmentation_loss: 0.0055 - kl_loss: 2.3467e-07
# Epoch 208/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 1.9878e-07
# Epoch 209/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0055 - segmentation_loss: 0.0055 - kl_loss: 1.8688e-07
# Epoch 210/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0053 - segmentation_loss: 0.0053 - kl_loss: 2.0373e-07
# Epoch 211/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 2.6971e-07
# Epoch 212/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0055 - segmentation_loss: 0.0055 - kl_loss: 1.9354e-07
# Epoch 213/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0088 - segmentation_loss: 0.0088 - kl_loss: 5.9515e-06
# Epoch 214/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0066 - segmentation_loss: 0.0066 - kl_loss: 2.4523e-07
# Epoch 215/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0060 - segmentation_loss: 0.0060 - kl_loss: 1.8828e-07
# Epoch 216/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0057 - segmentation_loss: 0.0057 - kl_loss: 1.9757e-07
# Epoch 217/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 2.0916e-07
# Epoch 218/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 2.0178e-07
# Epoch 219/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0054 - segmentation_loss: 0.0054 - kl_loss: 2.4789e-07
# Epoch 220/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0055 - segmentation_loss: 0.0055 - kl_loss: 2.2001e-07
# Epoch 221/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0052 - segmentation_loss: 0.0052 - kl_loss: 1.8442e-07
# Epoch 222/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0053 - segmentation_loss: 0.0053 - kl_loss: 2.5992e-07
# Epoch 223/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0051 - segmentation_loss: 0.0051 - kl_loss: 1.8618e-07
# Epoch 224/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0051 - segmentation_loss: 0.0051 - kl_loss: 1.7759e-07
# Epoch 225/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0052 - segmentation_loss: 0.0052 - kl_loss: 2.1574e-07
# Epoch 226/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0053 - segmentation_loss: 0.0053 - kl_loss: 2.6956e-07
# Epoch 227/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0051 - segmentation_loss: 0.0051 - kl_loss: 1.7583e-07
# Epoch 228/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0048 - segmentation_loss: 0.0048 - kl_loss: 1.9334e-07
# Epoch 229/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0049 - segmentation_loss: 0.0049 - kl_loss: 2.7142e-07
# Epoch 230/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0052 - segmentation_loss: 0.0052 - kl_loss: 1.4717e-06
# Epoch 231/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0054 - segmentation_loss: 0.0054 - kl_loss: 2.8282e-07
# Epoch 232/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0052 - segmentation_loss: 0.0052 - kl_loss: 2.0728e-07
# Epoch 233/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0061 - segmentation_loss: 0.0061 - kl_loss: 6.9350e-07
# Epoch 234/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0060 - segmentation_loss: 0.0060 - kl_loss: 1.9185e-07
# Epoch 235/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0053 - segmentation_loss: 0.0053 - kl_loss: 2.0529e-07
# Epoch 236/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0051 - segmentation_loss: 0.0051 - kl_loss: 1.8407e-07
# Epoch 237/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0051 - segmentation_loss: 0.0051 - kl_loss: 2.0340e-07
# Epoch 238/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0051 - segmentation_loss: 0.0051 - kl_loss: 2.2650e-07
# Epoch 239/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0056 - segmentation_loss: 0.0056 - kl_loss: 2.3579e-07
# Epoch 240/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0051 - segmentation_loss: 0.0051 - kl_loss: 2.0062e-07
# Epoch 241/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0049 - segmentation_loss: 0.0049 - kl_loss: 1.8320e-07
# Epoch 242/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0050 - segmentation_loss: 0.0050 - kl_loss: 2.2229e-07
# Epoch 243/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0061 - segmentation_loss: 0.0061 - kl_loss: 3.4536e-07
# Epoch 244/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0054 - segmentation_loss: 0.0054 - kl_loss: 2.1896e-07
# Epoch 245/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0055 - segmentation_loss: 0.0055 - kl_loss: 2.1786e-07
# Epoch 246/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0050 - segmentation_loss: 0.0050 - kl_loss: 2.1090e-07
# Epoch 247/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0050 - segmentation_loss: 0.0050 - kl_loss: 2.4017e-07
# Epoch 248/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0053 - segmentation_loss: 0.0053 - kl_loss: 1.2383e-06
# Epoch 249/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0048 - segmentation_loss: 0.0048 - kl_loss: 3.8557e-07
# Epoch 250/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0049 - segmentation_loss: 0.0049 - kl_loss: 2.0938e-07
# Epoch 251/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0050 - segmentation_loss: 0.0050 - kl_loss: 8.0291e-06
# Epoch 252/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0048 - segmentation_loss: 0.0048 - kl_loss: 1.6444e-07
# Epoch 253/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0050 - segmentation_loss: 0.0050 - kl_loss: 1.7285e-07
# Epoch 254/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0048 - segmentation_loss: 0.0048 - kl_loss: 1.7320e-07
# Epoch 255/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0050 - segmentation_loss: 0.0050 - kl_loss: 1.7391e-07
# Epoch 256/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0049 - segmentation_loss: 0.0049 - kl_loss: 1.7730e-07
# Epoch 257/2000
# 170/170 [==============================] - 2s 13ms/step - total_loss: 0.0052 - segmentation_loss: 0.0052 - kl_loss: 4.4197e-07
# Epoch 258/2000
# 170/170 [==============================] - 2s 14ms/step - total_loss: 0.0054 - segmentation_loss: 0.0054 - kl_loss: 4.8091e-07

# %%
## save model
unet_vae_model.encoder_unet.save('Unet_VAE_Models/encoder_unet_features_unet.h5')
unet_vae_model.decoder_unet.save('Unet_VAE_Models/decoder_unet_features_unet.h5')
unet_vae_model.encoder_vae.save('Unet_VAE_Models/encoder_vae_features_unet.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
